# %%
import pickle

# %%
data_path = "oldresults/LUNAR_MDP_rewards_data.pkl" 

with open(data_path, "rb") as f:
    loaded_data = pickle.load(f)

pg_rewards = loaded_data["PG"]
pgts_results = loaded_data["PGTS"]
experiment_times = loaded_data["TIMES"]

# %%
print(pg_rewards.shape)
for key in pgts_results.keys():
    print(pgts_results[key])
# Out:
# (1, 10)
# (1, 13)
# (1, 13)
# (1, 15)
# (1, 15)
# (1, 14)
# (1, 14)

# %%
print("Successfully loaded data!")
print("\n--- Training Times ---")
for method, time_taken in experiment_times.items():
    print(f"{method}: {time_taken:.2f} seconds")
# Out:
# Successfully loaded data!
#
# --- Training Times ---
# PG: 0.75 seconds
# PGTS_m1: 1.36 seconds
# PGTS_LAG_m1: 1.35 seconds
# PGTS_m2: 8.11 seconds
# PGTS_LAG_m2: 8.09 seconds
# PGTS_m3: 69.02 seconds
# PGTS_LAG_m3: 66.51 seconds
